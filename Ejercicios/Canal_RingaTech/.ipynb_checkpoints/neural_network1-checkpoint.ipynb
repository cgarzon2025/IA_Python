# %% [markdown]
# ## **Primera red neuronal con Tensorflow**

# %%
# Importamos las bibliotecas necesarias
import tensorflow as tf
import numpy as np

# Definimos los datos de entrada (celsius)
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# %%
# Crear la capa de entrada
capa = tf.keras.layers.Dense(units=1, input_shape=[1])

# Creamos el modelo
modelo = tf.keras.Sequential([capa])

# Compilamos el modelo
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
# Entrenamos el modelo
historial = modelo.fit(celsius, fahrenheit, epochs=1000, verbose=False)

# Imprimimos el resultado
print("Modelo entrenado!")
# Out:
# Modelo entrenado!

# %%
# Graficamos la pérdida
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de pérdida")
plt.plot(historial.history["loss"])
plt.show()

# %%
# Hacemos una predicción
print("Hacemos una predicción!")
resultado = modelo.predict(np.array([100.0]))
print("El resultado es " + str(resultado) + " fahrenheit!")
# Out:
# Hacemos una predicción!
# 1/1 [==============================] - 0s 41ms/step
# El resultado es [[211.74109]] fahrenheit!

# %%
# Mostramos los pesos y los sesgos
print("Vemos los pesos y los sesgos")
print(capa.get_weights())
# Out:
# Vemos los pesos y los sesgos
# [array([[1.7983543]], dtype=float32), array([31.90566], dtype=float32)]

# %%
# Vamos a agregar dos capas ocultas con 3 neuronas cada una 
capa1 = tf.keras.layers.Dense(units=3, input_shape=[1])
capa2 = tf.keras.layers.Dense(units=3)
salidas = tf.keras.layers.Dense(units=1)
modelo2 = tf.keras.Sequential([capa1, capa2, salidas])

# Compilamos el modelo
modelo2.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
# Entrenamos el modelo
historial = modelo2.fit(celsius, fahrenheit, epochs=1000, verbose=False)

# Imprimimos el resultado
print("Modelo 2 entrenado!")
# Out:
# Modelo 2 entrenado!

# %%
# Graficamos la pérdida
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de pérdida")
plt.plot(historial.history["loss"])
plt.show()

# %%
# Hacemos una predicción
print("Hacemos una predicción!")
resultado = modelo2.predict(np.array([100.0]))
print("El resultado es " + str(resultado) + " fahrenheit!")
# Mostramos los pesos y los sesgos
print("Vemos los pesos y los sesgos")
print(capa1.get_weights())
print(capa2.get_weights())
print(salidas.get_weights())
# Out:
# Hacemos una predicción!
# 1/1 [==============================] - 0s 56ms/step
# El resultado es [[211.74747]] fahrenheit!
# Vemos los pesos y los sesgos
# [array([[-0.5258672 , -0.39361775, -0.2875505 ]], dtype=float32), array([-3.5921648, -3.6022904,  2.531744 ], dtype=float32)]
# [array([[-0.9665329 ,  0.38713   , -1.2209257 ],
#        [-1.1102686 ,  0.02040779, -1.2471814 ],
#        [ 0.06400075,  0.03618486,  1.0653298 ]], dtype=float32), array([ 3.4820828 , -0.20515679,  3.5578353 ], dtype=float32)]
# [array([[0.7318689 ],
#        [0.00751463],
#        [1.3564353 ]], dtype=float32), array([3.3016903], dtype=float32)]

# %%
# Exportar el modelo en formato h5
modelo.save('celsius_to_fahrenheit.h5')
# Out:
# c:\Users\insit\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Comandos en linux para ver repositorio
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 262E-DAB9
#
#  Directory of c:\Users\insit\OneDrive - Insitel\Desktop\IA_Python\Ejercicios
#
# 05/05/2025  11:23 AM    <DIR>          .
# 05/05/2025  02:35 PM    <DIR>          ..
# 05/05/2025  11:23 AM    <DIR>          carpeta_salida
# 05/05/2025  03:03 PM            20,240 celsius_to_fahrenheit.h5
# 05/05/2025  09:51 AM           249,023 image_classifier.ipynb
# 05/05/2025  03:00 PM            54,953 neural_network1.ipynb
#                3 File(s)        324,216 bytes
#                3 Dir(s)  773,460,992,000 bytes free

# %%
# Creaar carpeta de salida
# !mkdir carpeta_salida
# Out:
# A subdirectory or file carpeta_salida already exists.

# %%
# !tensorflowjs_converter --input_format keras celsius_to_fahrenheit.h5 carpeta_salida/
# !python -m tf2onnx.convert --keras celsius_to_fahrenheit.h5 --output carpeta_salida/model.onnx
# Out:
# 2025-05-05 16:18:45.756194: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# c:\Users\insit\AppData\Local\Programs\Python\Python39\lib\runpy.py:127: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2025-05-05 16:18:49.501853: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2025-05-05 16:18:49.502594: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# c:\Users\insit\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Traceback (most recent call last):
#   File "c:\Users\insit\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\insit\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\insit\AppData\Local\Programs\Python\Python39\lib\site-packages\tf2onnx\convert.py", line 714, in <module>
#     main()
#   File "c:\Users\insit\AppData\Local\Programs\Python\Python39\lib\site-packages\tf2onnx\convert.py", line 248, in main
#     graph_def, inputs, outputs = tf_loader.from_keras(
#   File "c:\Users\insit\AppData\Local\Programs\Python\Python39\lib\site-packages\tf2onnx\tf_loader.py", line 669, in from_keras
#     keras_model = _keras.models.load_model(model_path, custom_objects)
#   File "c:\Users\insit\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "c:\Users\insit\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py", line 115, in _process_kwargs
#     raise TypeError(
# TypeError: weight_decay is not a valid argument, kwargs should be empty  for `optimizer_experimental.Optimizer`.
